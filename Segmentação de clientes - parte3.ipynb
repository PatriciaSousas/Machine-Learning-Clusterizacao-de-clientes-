# %% [markdown]
# # Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %% [markdown]
# # Carregando dados

# %%
df = pd.read_csv('BancoDeDados.csv')
df
# Out:
#         amostra                        id_cliente  \
# 0             0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1             1  8912fc0c3bbf1e2fbf35819e21706718
# 2             2  8912fc0c3bbf1e2fbf35819e21706718
# 3             3  f0ac8e5a239118859b1734e1087cbb1f
# 4             4  6bc8d08963a135220ed6c6d098831f84
# ...         ...                               ...
# 116576   116576  ce2172509c4149d65212484eb761bc37
# 116577   116577  ee1cfdc92e449920e25d3ca4ab4da4f6
# 116578   116578  ee1cfdc92e449920e25d3ca4ab4da4f6
# 116579   116579  ab0cf72dfe0538a63a57d6905ccb7b57
# 116580   116580  c61336d6c835632048f973d2f2db598d
#
#                         id_unico_cliente  item_id  cep_cliente  \
# 0       861eff4711a542e4b93843c6dd7febb0        1        14409
# 1       9eae34bbd3a474ec5d07949ca7de67c0        1        68030
# 2       9eae34bbd3a474ec5d07949ca7de67c0        2        68030
# 3       3c799d181c34d51f6d44bbbc563024db        1        92480
# 4       23397e992b09769faf5e66f9e171a241        1        25931
# ...                                  ...      ...          ...
# 116576  c5da6424f1f5decedef8672a1a0103e1        1        88350
# 116577  8d80e477643ec569b24592ce3d9dfc4c        1         9951
# 116578  8d80e477643ec569b24592ce3d9dfc4c        2         9951
# 116579  8c3c961a52bb5a0ffbce1d4e6d25cd67        1        35930
# 116580  428f4721a509be8c52de6ec2900ba918        1        12305
#
#          cidade_cliente estado_cliente                         id_pedido  \
# 0                franca             SP  00e7ee1b050b8499577073aeb2a297a1
# 1              santarem             PA  c1d2b34febe9cd269e378117d6681172
# 2              santarem             PA  c1d2b34febe9cd269e378117d6681172
# 3       nova santa rita             RS  b1a5d5365d330d10485e0203d54ab9e8
# 4                  mage             RJ  2e604b3614664aa66867856dba7e61b7
# ...                 ...            ...                               ...
# 116576          brusque             SC  edcf1e1eeb52381be9388c90152be52d
# 116577          diadema             SP  2ef4a11b6e24fdfbb43b92cb5f95edff
# 116578          diadema             SP  2ef4a11b6e24fdfbb43b92cb5f95edff
# 116579   joao monlevade             MG  2c12150c742ae2fa48bc703964c16c5f
# 116580          jacarei             SP  9f7ba492c273ffac8f90a623b8eadd3b
#
#        status_pedido       horario_pedido  ... pagamento_sequencial  \
# 0          delivered  2017-05-16 15:05:35  ...                    1
# 1          delivered  2017-11-09 00:50:13  ...                    1
# 2          delivered  2017-11-09 00:50:13  ...                    1
# 3          delivered  2017-05-07 20:11:26  ...                    1
# 4          delivered  2018-02-03 19:45:40  ...                    1
# ...              ...                  ...  ...                  ...
# 116576     delivered  2018-08-21 11:29:05  ...                    1
# 116577     delivered  2018-07-23 18:35:14  ...                    1
# 116578     delivered  2018-07-23 18:35:14  ...                    1
# 116579     delivered  2018-07-28 17:55:27  ...                    1
# 116580     delivered  2018-08-23 12:31:37  ...                    1
#
#        pagamento_tipo pagamento_prestacoes pagamento_valor review  \
# 0         credit_card                    2          146.87      4
# 1         credit_card                    1          275.79      1
# 2         credit_card                    1          275.79      1
# 3         credit_card                    7          140.61      3
# 4         credit_card                   10          137.58      4
# ...               ...                  ...             ...    ...
# 116576    credit_card                    5          314.32      5
# 116577    credit_card                    1           84.63      3
# 116578    credit_card                    1           84.63      3
# 116579    credit_card                    7           77.50      5
# 116580         boleto                    1           24.69      5
#
#                  categoria       categoria_ingles  cep_vendedor  \
# 0        moveis_escritorio       office_furniture          8577
# 1        moveis_escritorio       office_furniture          8577
# 2        moveis_escritorio       office_furniture          8577
# 3        moveis_escritorio       office_furniture          8577
# 4        moveis_escritorio       office_furniture          8577
# ...                    ...                    ...           ...
# 116576  artes_e_artesanato  arts_and_craftmanship         95910
# 116577  artes_e_artesanato  arts_and_craftmanship         17201
# 116578  artes_e_artesanato  arts_and_craftmanship         17201
# 116579  artes_e_artesanato  arts_and_craftmanship         17201
# 116580  artes_e_artesanato  arts_and_craftmanship         17201
#
#         cidade_vendedor  estado_vendedor
# 0       itaquaquecetuba               SP
# 1       itaquaquecetuba               SP
# 2       itaquaquecetuba               SP
# 3       itaquaquecetuba               SP
# 4       itaquaquecetuba               SP
# ...                 ...              ...
# 116576          lajeado               RS
# 116577              jau               SP
# 116578              jau               SP
# 116579              jau               SP
# 116580              jau               SP
#
# [116581 rows x 27 columns]

# %% [markdown]
# #  Análise Exploratória dos Dados

# %%
#abro uma funcao em grafico de barras para entender os valores percentuais
# dos estados 

def plot_perc(st,dados):
    plt.figure(figsize=(20,8))

    g = sns.countplot(x=st, data=dados, orient='h')
    g.set_title("Distribuição do estado dos clientes", fontsize=20)
    g.set_xlabel("Estado", fontsize=17)
    g.set_ylabel("Contagem", fontsize=17)
    g.set_xticklabels(g.get_xticklabels(),rotation=45)
    sizes = []
    for p in g.patches:
        height = p.get_height()
        sizes.append(height)
        g.text(p.get_x()+p.get_width()/1.6,
            height + 200,
            '{:1.2f}%'.format(height/116581*100),
            ha="center", va='bottom',fontsize=12) 
    g.set_ylim(0, max(sizes) * 1.1)

# %%
#Distribuicao por estado

plot_perc('estado_cliente',df)

# %%
#distribuicao por estados de clientes 


plot_perc('estado_vendedor',df)

# %% [markdown]
# - Identifiquei primeiramente que a maioria dos clientes realiza compras por cartão de crédito,
# - posteriormente por boleto, voucher e cartão de débito. Seria interessante aumentar as promoções para pagamento à vista (para aumento dos pagamentos com boleto ou cartão de débito).
# - Também percebe-se que a maioria dos vendedores e compradores estão em SP.
# - Também vou criar um novo banco de dados apenas com as informações que vou precisar para fazer a análise de recẽncia, frequência e receita.

# %%
#construção do banco de dados com os dados que eu quero utiliza 

df_olist = df[['id_unico_cliente', 'id_cliente', 'horario_pedido', 'item_id', 'preco']]

# %%
#construção do banco de dados com os dados que eu quero utiliza 
df_compra = df.groupby('id_unico_cliente').horario_pedido.max().reset_index()
df_compra.columns = ['id_unico_cliente', 'DataMaxCompra']

# %%
df_compra['DataMaxCompra']= pd.to_datetime(df_compra['DataMaxCompra'])

# %% [markdown]
# - Defino gora as três variáveis que utilizaremos para segmentação: recência, frequência e receita. Em inglês, é chamado de método RFM
# - Recência: quão recentemente um cliente fez uma compra
# - Frequência: com que frequência um cliente faz uma compra
# - Receita: quanto dinheiro um cliente gasta em compras.

# %%
#seleciona o ponto de observação como a data máxima de compra em df
df_compra['Recencia'] = (df_compra['DataMaxCompra'].max() - df_compra['DataMaxCompra']).dt.days

#junta esse df com o  novo chamado df_user
df_usuario = pd.merge(df_olist, df_compra[['id_unico_cliente','Recencia']], on='id_unico_cliente')

df_usuario.head()
# Out:
#                    id_unico_cliente                        id_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1  9eae34bbd3a474ec5d07949ca7de67c0  8912fc0c3bbf1e2fbf35819e21706718
# 2  9eae34bbd3a474ec5d07949ca7de67c0  8912fc0c3bbf1e2fbf35819e21706718
# 3  3c799d181c34d51f6d44bbbc563024db  f0ac8e5a239118859b1734e1087cbb1f
# 4  23397e992b09769faf5e66f9e171a241  6bc8d08963a135220ed6c6d098831f84
#
#         horario_pedido  item_id   preco  Recencia
# 0  2017-05-16 15:05:35        1  124.99       474
# 1  2017-11-09 00:50:13        1  112.99       298
# 2  2017-11-09 00:50:13        2  112.99       298
# 3  2017-05-07 20:11:26        1  124.99       483
# 4  2018-02-03 19:45:40        1  106.99       211

# %%
# ploto a distribuição da feature continua que acabo de identificar
#def dist(dados):
#    sns.set(palette='muted', color_codes=True, style='white')
#    fig, ax = plt.subplots(figsize=(12, 6))
#    sns.despine(left=True)
#    sns.distplot(dados, bins=30)
#    plt.show()

# %%
def calcular_wcss(data):
    wcss = []
    for k in range(1, 10):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(X=data)
        data["clusters"] = kmeans.labels_
        wcss.append(kmeans.inertia_)
    return wcss

# %% [markdown]
# - Aplico o o Método Cotovelo, a ideia é rodar o KMeans para várias quantidades diferentes de clusters
# - e dizer qual dessas quantidades é o número ótimo de clusters. Usando a "regra do cotovelo", identifico que a partir de 4 clusters teremos bons resultados. Vou usar 5 apenas para garanti

# %%
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
from sklearn.cluster import KMeans

df_recencia = df_usuario[['Recencia']]
soma_quadrados = calcular_wcss(df_recencia)

# %%
#Plote do metodo cotovelo 

plt.figure(figsize=(10, 5))
plt.plot(soma_quadrados)
plt.xlabel("Número de Clusters")
plt.show()

# %%
import math
def numero_otimo_clusters(wcss):
    x1, y1 = 2, wcss[0]
    x2, y2 = 20, wcss[len(wcss)-1]

    distancias = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerador = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominador = math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distancias.append(numerador/denominador)
    
    return distancias.index(max(distancias)) + 2

# %%
# calculando a soma dos quadrados para as quantidade de clusters
soma_quadrados = calcular_wcss(df_recencia)

# calculando a quantidade ótima de clusters
n = numero_otimo_clusters(soma_quadrados)

# %%
# rodando o kmeans para  quantidade ótima de clusters
kmeans = KMeans(n_clusters=4)
df_usuario['RecenciaCluster'] = kmeans.fit_predict(df_recencia)

# %%
#função para ordenar o número de clusters 
def ordenar_cluster(cluster_nome, target_nome,df,ascending):
    novo_nome = 'novo' + cluster_nome
    agrupado_por_cluster = df.groupby(cluster_nome)[target_nome].mean().reset_index()
    agrupado_por_cluster_ordenado = agrupado_por_cluster.sort_values(by=target_nome,
                                                                     ascending=ascending).reset_index(drop=True)
    agrupado_por_cluster_ordenado['index'] = agrupado_por_cluster_ordenado.index
    juntando_cluster = pd.merge(df,agrupado_por_cluster_ordenado[[cluster_nome,'index']], on=cluster_nome)
    removendo_dados = juntando_cluster.drop([cluster_nome],axis=1)
    df_final = removendo_dados.rename(columns={"index":cluster_nome})
    return df_final

df_usuario = ordenar_cluster('RecenciaCluster', 'Recencia',df_usuario,False)

# %%
df_usuario.groupby('RecenciaCluster')['Recencia'].describe()
# Out:
#                    count        mean        std    min    25%    50%    75%  \
# RecenciaCluster
# 0                20697.0  489.070832  59.862148  404.0  441.0  480.0  532.0
# 1                30695.0  318.687376  43.450070  253.0  281.0  312.0  355.0
# 2                33601.0  187.076277  35.024122  127.0  157.0  187.0  217.0
# 3                31588.0   66.405850  35.800016    0.0   33.0   67.0   99.0
#
#                    max
# RecenciaCluster
# 0                728.0
# 1                403.0
# 2                252.0
# 3                126.0

# %%
# crio um df com a quantidade de ordens para cada cliente
df_frequencia = df.groupby('id_unico_cliente').pedido_aprovado.count().reset_index()
df_frequencia.columns = ['id_unico_cliente','Frequencia']

# adiciono esses dados em df principal
df_usuario = pd.merge(df_usuario, df_frequencia, on='id_unico_cliente')

# %%
df_usuario.head()
# Out:
#                    id_unico_cliente                        id_cliente  \
# 0  861eff4711a542e4b93843c6dd7febb0  06b8999e2fba1a1fbc88172c00ba8bc7
# 1  3c799d181c34d51f6d44bbbc563024db  f0ac8e5a239118859b1734e1087cbb1f
# 2  567ab47ca4deb92d46dbf54dce07d0a7  fd3a0b1bd209f0e7d420c9c3d1127613
# 3  f40ab89b622248b7ca125af4b486b887  fbd40c083aa8cddebb5265b2ba6aaf2e
# 4  749943913a9851a39c9baf51877fbab6  10558ef4afea173bfb5e2cbe3d5b0bb5
#
#         horario_pedido  item_id   preco  Recencia  RecenciaCluster  Frequencia
# 0  2017-05-16 15:05:35        1  124.99       474                0           1
# 1  2017-05-07 20:11:26        1  124.99       483                0           1
# 2  2017-03-23 15:10:17        1  126.99       528                0           1
# 3  2017-05-16 10:00:49        1  124.99       474                0           1
# 4  2017-03-18 23:04:36        1  126.99       533                0           1

# %%
# rodo o kmeans para quantidade ótima de clusters
df_frequencia = df_usuario[['Frequencia']]
kmeans = KMeans(n_clusters=4)
df_usuario['FrequenciaCluster'] = kmeans.fit_predict(df_frequencia)

# %%
# ordena os clusters de frequência
df_usuario.groupby('FrequenciaCluster')['Frequencia'].describe()
# Out:
#                       count       mean       std   min   25%   50%   75%   max
# FrequenciaCluster
# 0                  106570.0   1.306343  0.570539   0.0   1.0   1.0   2.0   3.0
# 1                     514.0  24.447471  5.669776  16.0  20.0  24.0  24.0  38.0
# 2                    9422.0   5.848015  2.496369   4.0   4.0   5.0   6.0  15.0
# 3                      75.0  75.000000  0.000000  75.0  75.0  75.0  75.0  75.0

# %%
#calcula a receita para cada cliente
df_receita = df.groupby('id_unico_cliente').pagamento_valor.sum().reset_index()

#junta com o df principal
df_usuario = pd.merge(df_usuario, df_receita, on='id_unico_cliente')

# %%
# rodando o kmeans para  quantidade ótima de clusters
df_pagamento = df_usuario[['pagamento_valor']]
kmeans = KMeans(n_clusters=4)
df_usuario['ReceitaCluster'] = kmeans.fit_predict(df_pagamento)

# %%
#ordena os clusters
df_usuario.groupby('ReceitaCluster')['pagamento_valor'].describe()
# Out:
#                    count           mean           std        min        25%  \
# ReceitaCluster
# 0               114709.0     256.843780    360.390633       9.59      69.85
# 1                  199.0   26914.634523  10065.864450   16313.60   19167.26
# 2                 1665.0    5510.153423   2784.346269    2889.60    3472.96
# 3                    8.0  109312.640000      0.000000  109312.64  109312.64
#
#                       50%        75%        max
# ReceitaCluster
# 0                  132.49     268.77    2869.25
# 1                22346.60   30186.00   45256.00
# 2                 4345.50    6718.39   14963.64
# 3               109312.64  109312.64  109312.64

# %%
df_final = df_usuario.drop(['id_cliente','horario_pedido','item_id','preco'],axis=1)
df_final.head()
# Out:
#                    id_unico_cliente  Recencia  RecenciaCluster  Frequencia  \
# 0  861eff4711a542e4b93843c6dd7febb0       474                0           1
# 1  3c799d181c34d51f6d44bbbc563024db       483                0           1
# 2  567ab47ca4deb92d46dbf54dce07d0a7       528                0           1
# 3  f40ab89b622248b7ca125af4b486b887       474                0           1
# 4  749943913a9851a39c9baf51877fbab6       533                0           1
#
#    FrequenciaCluster  pagamento_valor  ReceitaCluster
# 0                  0           146.87               0
# 1                  0           140.61               0
# 2                  0           142.05               0
# 3                  0           155.70               0
# 4                  0           148.33               0

# %%
#renomeando as colunas
df_final.columns = ['Id_unico_cliente', 'Recencia', 'RecenciaCluster', 'Frequencia', 'FrequenciaCluster', 'Receita', 'ReceitaCluster']
df_final.head()
# Out:
#                    Id_unico_cliente  Recencia  RecenciaCluster  Frequencia  \
# 0  861eff4711a542e4b93843c6dd7febb0       474                0           1
# 1  3c799d181c34d51f6d44bbbc563024db       483                0           1
# 2  567ab47ca4deb92d46dbf54dce07d0a7       528                0           1
# 3  f40ab89b622248b7ca125af4b486b887       474                0           1
# 4  749943913a9851a39c9baf51877fbab6       533                0           1
#
#    FrequenciaCluster  Receita  ReceitaCluster
# 0                  0   146.87               0
# 1                  0   140.61               0
# 2                  0   142.05               0
# 3                  0   155.70               0
# 4                  0   148.33               0

# %%
df_final = ordenar_cluster('FrequenciaCluster', 'ReceitaCluster',df_final,False)

# %% [markdown]
# Calculo a pontuação geral do cliente baseado nesses clusters e também defino 4 opções: inativo, business, master e premium

# %%
df_final['Pontuacao'] = df_usuario['RecenciaCluster'] + df_usuario['FrequenciaCluster'] + df_usuario['ReceitaCluster']
df_final.groupby('Pontuacao')['Recencia','Frequencia','Receita'].mean()
df_final.head()
# Out:
#                    Id_unico_cliente  Recencia  RecenciaCluster  Frequencia  \
# 0  861eff4711a542e4b93843c6dd7febb0       474                0           1
# 1  3c799d181c34d51f6d44bbbc563024db       483                0           1
# 2  567ab47ca4deb92d46dbf54dce07d0a7       528                0           1
# 3  f40ab89b622248b7ca125af4b486b887       474                0           1
# 4  749943913a9851a39c9baf51877fbab6       533                0           1
#
#    Receita  ReceitaCluster  FrequenciaCluster  Pontuacao
# 0   146.87               0                  2          0
# 1   140.61               0                  2          0
# 2   142.05               0                  2          0
# 3   155.70               0                  2          0
# 4   148.33               0                  2          0

# %%
df_final['Segmento'] = 'Inativo'

# %%
df_final.loc[df_final['Pontuacao']>=3,'Segmento'] = 'Business' 
df_final.loc[df_final['Pontuacao']>=6,'Segmento'] = 'Master' 
df_final.loc[df_final['Pontuacao']>=8,'Segmento'] = 'Premium'

# %%
df_final.to_csv('RFM.csv')

# %%
def plot_segmento(x,y,data):
    sns.set(palette='muted', color_codes=True, style='whitegrid')
    fig, axs = plt.subplots(1, 1, figsize=(7, 5))
    sns.despine(left=True)
    sns.scatterplot(x=x, y=y, hue='Segmento', data=data, size='Segmento', sizes=(50,150), size_order=['Premium','Master','Business','Inativo'])
    axs.set_title('Segmento de Cliente')
    plt.show()

# %%
plot_segmento('Recencia','Frequencia',df_final)

# %%
plot_segmento('Recencia','Receita',df_final)

# %%
plot_segmento('Frequencia','Receita',df_final)
